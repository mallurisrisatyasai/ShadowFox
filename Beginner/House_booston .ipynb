# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
house=pd.read_csv("HousingData.csv")

# %%
house
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90    NaN  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99    NaN  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# ## Data preprocessing

# %%
house.head(3)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7

# %%
house.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
sns.heatmap(house.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ## Data filling having null values

# %%
house.fillna(house.mean(), inplace=True)

# %%
house.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# ## Use Machine learning
# ## Divide the Data into training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
X = house.drop("MEDV", axis=1)
y = house['MEDV']
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.33,random_state=3)

# %%
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.200000  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.900000  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.100000  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.800000  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.200000  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...        ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.100000  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.700000  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.000000  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.300000  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  68.518519  2.5050    1  273
#
#      PTRATIO       B      LSTAT
# 0       15.3  396.90   4.980000
# 1       17.8  396.90   9.140000
# 2       17.8  392.83   4.030000
# 3       18.7  394.63   2.940000
# 4       18.7  396.90  12.715432
# ..       ...     ...        ...
# 501     21.0  391.99  12.715432
# 502     21.0  396.90   9.080000
# 503     21.0  396.90   5.640000
# 504     21.0  393.45   6.480000
# 505     21.0  396.90   7.880000
#
# [506 rows x 13 columns]

# %% [markdown]
# ## Linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
housedata=LinearRegression()

# %%
housedata.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
housedata.coef_,housedata.intercept_
# Out:
# (array([-1.33710837e-01,  3.02273341e-02, -1.04835355e-01,  4.44008254e+00,
#         -1.06589096e+01,  4.11239130e+00, -9.92722470e-03, -1.17081881e+00,
#          2.36980190e-01, -5.41437466e-03, -8.40423556e-01,  1.20972716e-02,
#         -5.11584737e-01]),
#  np.float64(26.424791802879767))

# %%
predict = housedata.predict(X_test)

# %%
predict,y_test
# Out:
# (array([38.33781817, 18.89856096, 24.19367235, 32.18733968, 24.73307017,
#         23.36270261, 19.83220202,  5.83710296, 21.49556096, 17.73635209,
#         11.64103319, 32.18323831, 35.78288064, 30.76322176,  6.68699274,
#         11.21499056, 23.38549302, 14.52336911, 12.38772557, 29.09399285,
#         27.33137142, 35.60976927, 26.82109887, 21.51124192, 13.66604077,
#         25.65270847, 20.77576753, 17.97320983, 20.05362877, 24.17972568,
#         14.98410085, 33.52777963, 21.86998682, 19.22710976, 17.40624706,
#         23.47556651, 22.14637   , 32.90318322, 16.07477129, 22.64474027,
#         17.13981279,  9.96156319, 25.23172651, 18.88308101, 25.75788904,
#         26.20633354, 26.55273297, 17.87475928, 28.02480252, 20.77283908,
#         20.90365136, 19.64988942, 38.23149309, 18.38626449, 25.2609901 ,
#          9.3042586 , 36.13480499, 15.89808878, 31.35255754, 19.62675554,
#         23.424132  , 22.98422193, 32.69956236, 32.64827366, 20.67967589,
#         23.47995931, 33.96070165, 23.21041994, 28.68659116, 29.58133371,
#         25.36540989, 27.71168551, 21.66054677, 31.75480184, 11.86420895,
#         23.65265844, 25.145622  , 25.88428809, 24.54860068, 19.86405007,
#         26.87294958, 20.46282028,  7.75686612, 20.00641987, 26.91245234,
#         13.59374723, 23.81426891, 14.37661429, 21.99644105, 25.23416167,
#         20.00897371, 20.85184223, 22.88577944, 39.86288141, 31.11303844,
#         15.67682943, 41.93969374, 15.61354541, 23.87328873, 34.80881998,
#         23.36543529, 23.01607695, 15.08098441, 22.70703419, 33.67862606,
#         10.94974928, 20.85579645, 10.94235788, 21.51371252, 36.40274544,
#         20.30611962, 19.38271587, 15.33526646, 25.33831573, 25.04191708,
#         19.45096007, 32.66183824, 28.90722327, 18.4035878 , 28.45951507,
#         12.31876587,  6.62640283, 19.77612045, 21.4762472 , 14.45542745,
#         18.48393415, 19.2330922 , 31.37785544, 12.67211208, 22.73356875,
#         25.77110994, 40.5912781 , 21.56968217, 30.84037499, 21.7152801 ,
#         16.08143948, 25.24697301,  8.95333503, 18.26850008, 28.3124876 ,
#          8.79866266, 28.3754289 , 26.12482594, 21.75523774, -0.26113437,
#         40.66846762, 17.68269482, 24.39994207, 18.47211995, 18.57741009,
#         14.77688672, 26.00949062, 21.22590912,  0.10837202, 35.85424614,
#         36.99883617, 26.14127704, 20.94534961, 40.73164164, 30.98786637,
#         15.69361153, 18.43731886, 15.83383302, 28.04918033, 20.00439793,
#         16.71266936, 27.93587377]),
#  224    44.8
#  137    17.1
#  453    17.8
#  303    33.1
#  254    21.9
#         ...
#  355    20.6
#  301    22.0
#  286    20.1
#  244    17.6
#  243    23.7
#  Name: MEDV, Length: 167, dtype: float64)

# %%
plt.scatter(y_test,predict)

# %% [markdown]
# Evaluation Metrics

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
#For linear regression
print("Mean absolute Error is:")
mean_absolute_error(y_test,predict)
# Out:
# Mean absolute Error is:
# 3.5386410475690084

# %%
print("Mean squared Error is:")
mean_squared_error(y_test,predict)
# Out:
# Mean squared Error is:
# 23.91822681903297

# %%
print("R2 Error:")
r2_score(y_test,predict)
# Out:
# R2 Error:
# 0.70598937252855

# %%
plt.scatter(y_test,predict)
plt.xlabel("Actual House Prices")
plt.ylabel("Predicted House Prices")
plt.title("Actual vs Predicted Prices")
plt.show()

# %% [markdown]
# ## predecting the MEDV

# %%
input_data = [
    0.02731,
    0.0,
    7.07,
    0,
    0.469,
    6.421,
    78.9,
    4.9671,
    2,
    242,
    17.8,
    396.90,
    9.14
]
predicted = housedata.predict([input_data])
print(f"The predicted house price is: {predicted[0]}")
# Out:
# The predicted house price is: 24.817422995814326
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
